# %% [markdown]
# # Lab 1 Unity catalog and SQL
#
# ## Exercise 1 Catalogs, databases and schemas
#
# a) Login to Databricks with your account and the password from your instructor.
#
# b) Create a new notebook and call it Unity catalog and SQL. Select SQL as default language for your notebook. Just use Serverless compute.
#
# c) Try to create a catalog using SQL syntax - you will get an error if you do not specify a location. Copy the location from the Storage root for the default catalog in Unity Catalog Explorer on the Details pane.
# You will then get another error: You do not have permission to create a catalog.
#
# d) Write a USE CATALOG statement to select the catalog with your name as default catalog
#
# e) Check that the current catalog is the one you just set. Use a SELECT statement for this and a function called current_catalog()
#
# f) Create a schema called Sales and another called HR.
#
# g) Create a database called Marketing. Please notice schema and database is the same in Spark.
#
# h) Study the catalogs and schemas in the Catalog view in the left panel. Are there any names with capitalized letters or was HR magically translated into hr?

# %% [markdown]
# ## Exercise 2 Tables
#
# a) Create a table called student in the sales schema, where you can register firstname, lastname, dob, iswizard,weight and height. Use the AI agent to generate the SQL code if you don't feel confident to write it your self.
#
# b) Insert a row into your table for Harry Potter, 31/7-1980, True, 67.5 kg and 180 cm.
#
# c) Update the firstname to Harry James
#
# d) Add a constraint to the table to let firstname and lastname be a primary key for the table. Both columns need to be NOT NULL for this. You can recreate the table easily with the CREATE OR REPLACE TABLE statement if necessary.
#
# e) Now run the INSERT statement from step b twice in a row
#
# f) Query the table and check for duplicates. The primary key is not enforced in a Databricks table - it's only for informational purposes. See https://docs.databricks.com/aws/en/tables/constraints

# %% [markdown]
# ## Exercise 3 Import tables
#
# a) Import the Department.csv file into a table called Department in the hr schema. Use the Catalog Explorer for the import.
#
# b) Query the table in a cell in your notebook and find the departments without a sales target
#
# c) Create a volume called Teashop_Volume in your own catalog under the hr schema
#
# d) Upload the Employees.csv file to the volume
#
# d) Import the Employees.csv file using Python code. Save the data in a table called Employee in the hr schema
#
# e) Create a SELECT query to display the fullname for each employee in one single colum called Employee Name

# %% [markdown]
# ## Exercise 4 Views
#
# a) Create a view which is an INNER JOIN of the two tables hr.Employees and hr.Department to display the name of the department, the employeeId and the full name for each employee.
#
# b) Notice the view and the tables are visible in the Catalog explorer.  Study the lineage diagram for the view and the tables.

# %% [markdown]
# ## Exercise 5 UDF
#
# a) Create a userdefined function called getAge, which computes the age from a given date.
#
# b) Test that your function works with the current date.

# %% [markdown]
# ## Exercise 6 Temporary views
#
# a) Create a temporary view which contains name of the students from sales.students and their age.
#
# b) Notice the temporary view is not visible in Catalog explorer
